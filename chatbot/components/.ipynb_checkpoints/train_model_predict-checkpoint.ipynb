# %%
import pickle
import json
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import SGD
import random
import nltk
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

# %%
# Download required data from nltk.
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\shefi\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\shefi\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\wordnet.zip.
# True

# %%
words = []
classes = []
documents = []
ignore_letters = ['!', '?', ',', '.']
intents_file = open('intents.json').read()
intents = json.loads(intents_file)

for intent in intents['intents']:
    for pattern in intent['patterns']:
        # tokenize each word
        word = nltk.word_tokenize(pattern)
        words.extend(word)
        # add documents in the corpus
        documents.append((word, intent['tag']))
        # add to our classes list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])
print(documents)
# lemmaztize and lower each word and remove duplicates
words = [lemmatizer.lemmatize(w.lower())
         for w in words if w not in ignore_letters]
words = sorted(list(set(words)))
# sort classes
classes = sorted(list(set(classes)))
# documents = combination between patterns and intents
print(len(documents), "documents")
# classes = intents
print(len(classes), "classes", classes)
# words = all words, vocabulary
print(len(words), "unique lemmatized words", words)

pickle.dump(words, open('words.pkl', 'wb'))
pickle.dump(classes, open('classes.pkl', 'wb'))

# create our training data
training = []
# create an empty array for our output
output_empty = [0] * len(classes)
# training set, bag of words for each sentence
for doc in documents:
    # initialize our bag of words
    bag = []
    # list of tokenized words for the pattern
    pattern_words = doc[0]
    # lemmatize each word - create base word, in attempt to represent related words
    pattern_words = [lemmatizer.lemmatize(
        word.lower()) for word in pattern_words]
    # create our bag of words array with 1, if word match found in current pattern
    for word in words:
        bag.append(1) if word in pattern_words else bag.append(0)

    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1

    training.append([bag, output_row])
# shuffle our features and turn into np.array
random.shuffle(training)
training = np.array(training)
# create train and test lists. X - patterns, Y - intents
train_x = list(training[:, 0])
train_y = list(training[:, 1])
print("Training data created")

# Create model - 3 layers. First layer 128 neurons, second layer 64 neurons and 3rd output layer contains number of neurons
# equal to number of intents to predict output intent with softmax
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

# Compile model. Stochastic gradient descent with Nesterov accelerated gradient gives good results for this model
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy',
              optimizer=sgd, metrics=['accuracy'])

# fitting and saving the model
hist = model.fit(np.array(train_x), np.array(train_y),
                 epochs=200, batch_size=5, verbose=1)
model.save('chatbot_model.h5', hist)

print("model created")
# Out:
# [(['Hi', 'there'], 'greeting'), (['How', 'are', 'you'], 'greeting'), (['Is', 'anyone', 'there', '?'], 'greeting'), (['Hey'], 'greeting'), (['Hola'], 'greeting'), (['Hello'], 'greeting'), (['Heylo'], 'greeting'), (['Bye'], 'goodbye'), (['See', 'you', 'later'], 'goodbye'), (['Goodbye'], 'goodbye'), (['Nice', 'chatting', 'to', 'you', ',', 'bye'], 'goodbye'), (['Till', 'next', 'time'], 'goodbye'), (['Cya'], 'goodbye'), (['Bubye'], 'goodbye'), (['What', 'is', 'a', 'coronavirus'], 'What is a coronavirus?'), (['What', 'is', 'covid', '19'], 'What is COVID-19?'), (['symptoms', 'of', 'covid', '19'], 'What are the symptoms of COVID 19?'), (['symptoms', 'of', 'coronavirus'], 'What are the symptoms of COVID 19?'), (['covid', '19', 'symptoms'], 'What are the symptoms of COVID 19?'), (['coronavirus', 'symptoms'], 'What are the symptoms of COVID 19?'), (['How', 'does', 'COVID', '19', 'spread'], 'How does COVID 19 spread?'), (['How', 'does', 'coronavirus', 'spread'], 'How does COVID 19 spread?'), (['What', 'can', 'I', 'do', 'to', 'protect', 'myself', 'and', 'prevent', 'the', 'spread', 'of', 'disease'], 'What can I do to protect myself and prevent the spread of disease?'), (['Protection', 'measures', 'for', 'everyone'], 'What can I do to protect myself and prevent the spread of disease?'), (['prevent', 'the', 'spread', 'of', 'disease'], 'What can I do to protect myself and prevent the spread of disease?'), (['How', 'likely', 'am', 'I', 'to', 'catch', 'COVID', '19'], 'How likely am I to catch COVID-19?'), (['How', 'likely', 'am', 'I', 'to', 'catch', 'coronavirus'], 'How likely am I to catch COVID-19?'), (['effected', 'by', 'coronavirus'], 'How likely am I to catch COVID-19?'), (['Should', 'I', 'worry', 'about', 'COVID', '19'], 'Should I worry about COVID-19'), (['Should', 'I', 'worry', 'about', 'coronavirus'], 'Should I worry about COVID-19'), (['antibiotics', 'effective', 'in', 'preventing', 'treating', 'the', 'COVID', '19'], 'Are antibiotics effective in preventing or treating the COVID-19'), (['antibiotics', 'effective', 'in', 'preventing', 'treating', 'the', 'coronavirus'], 'Are antibiotics effective in preventing or treating the COVID-19'), (['antibiotic', 'effective', 'in', 'coronavirus'], 'Are antibiotics effective in preventing or treating the COVID-19'), (['Are', 'there', 'any', 'medicines', 'or', 'therapies', 'that', 'can', 'prevent', 'or', 'cure', 'COVID', '19'], 'Are there any medicines or therapies that can prevent or cure COVID-19'), (['Are', 'there', 'any', 'medicines', 'or', 'therapies', 'that', 'can', 'prevent', 'or', 'cure', 'coronavirus'], 'Are there any medicines or therapies that can prevent or cure COVID-19'), (['Is', 'there', 'a', 'vaccine', ',', 'drug', 'or', 'treatment', 'for', 'COVID', '19'], 'Is there a vaccine, drug or treatment for COVID-19'), (['Is', 'there', 'a', 'vaccine', ',', 'drug', 'or', 'treatment', 'for', 'coronavirus'], 'Is there a vaccine, drug or treatment for COVID-19'), (['How', 'long', 'can', 'you', 'test', 'positive', 'after', 'having', 'COVID-19', '?'], 'How long can you test positive'), (['How', 'long', 'can', 'you', 'test', 'positive', 'after', 'having', 'coronavirus', '?'], 'How long can you test positive'), (['How', 'long', 'can', 'COVID-19', 'vaccine', 'side', 'effects', 'last', '?'], 'vaccine side effects last'), (['How', 'long', 'can', 'coronavirus', 'vaccine', 'side', 'effects', 'last', '?'], 'vaccine side effects last'), (['Can', 'you', 'get', 'COVID-19', 'by', 'touching', 'surfaces', '?'], 'get virus by touching surfaces'), (['Can', 'you', 'get', 'coronavirus', 'by', 'touching', 'surfaces', '?'], 'get virus by touching surfaces'), (['What', 'is', 'the', 'incubation', 'period', '?'], 'incubation period'), (['What', 'is', 'the', 'incubation', 'period', '?'], 'incubation period'), (['How', 'can', 'I', 'prevent', 'COVID-19', '?'], 'prevent COVID-19'), (['How', 'can', 'I', 'prevent', 'coronavirus', '?'], 'prevent COVID-19'), (['What', 'is', 'the', 'difference', 'between', 'a', "'three", 'dose',  ...
# 68 documents
# 25 classes ['Are antibiotics effective in preventing or treating the COVID-19', 'Are there any medicines or therapies that can prevent or cure COVID-19', 'COVID-19 vaccine cause a COVID-19 infection', 'COVID-19 vaccine different from the influenza (flu) vaccine', 'How does COVID 19 spread?', 'How likely am I to catch COVID-19?', 'How long can you test positive', 'Is there a vaccine, drug or treatment for COVID-19', 'Should I worry about COVID-19', 'Transportation to COVID-19 vaccination clinics', 'What are the symptoms of COVID 19?', 'What can I do to protect myself and prevent the spread of disease?', 'What is COVID-19?', 'What is a coronavirus?', 'Why would I want to get the COVID-19 vaccine', 'appointment if I do not have an Ontario health card', "difference between a 'three dose primary series' and a 'booster dose'?", 'get virus by touching surfaces', 'goodbye', 'greeting', 'incubation period', 'prevent COVID-19', 'thanks', 'third (booster) dose of the COVID-19 vaccine', 'vaccine side effects last']
# 135 unique lemmatized words ["'", "'booster", "'s", "'three", '(', ')', '19', 'a', 'about', 'after', 'alot', 'am', 'an', 'and', 'antibiotic', 'any', 'anyone', 'appointment', 'are', 'awesome', 'between', 'book', 'booster', 'bubye', 'by', 'bye', 'can', 'card', 'catch', 'cause', 'chatting', 'clinic', 'coronavirus', 'covid', 'covid-19', 'cure', 'cya', 'difference', 'different', 'disease', 'do', 'doe', 'dose', 'drug', 'effect', 'effected', 'effective', 'even', 'everyone', 'flu', 'follow', 'for', 'from', 'get', 'goodbye', 'have', 'having', 'health', 'hello', 'helpful', 'helping', 'hey', 'heylo', 'hi', 'hola', 'how', 'i', 'if', 'in', 'incubation', 'infection', 'influenza', 'is', 'last', 'later', 'likely', 'long', 'major', 'me', 'measure', 'medicine', 'much', 'myself', 'next', 'nice', 'not', 'of', 'ontario', 'or', 'para', 'period', 'positive', 'prevent', 'preventing', 'primary', 'protect', 'protection', 'public', 'red', 'required', 'see', 'series', 'should', 'side', 'so', 'spread', 'still', 'surface', 'symptom', 'test', 'thank', 'thanks', 'that', 'the', 'therapy', 'there', 'third', 'till', 'time', 'to', 'touching', 'transpo', 'transportation', 'treating', 'treatment', 'vaccination', 'vaccine', 'want', 'we', 'what', 'white', 'why', 'worry', 'would', 'you']
# Training data created
# C:\Users\shefi\AppData\Local\Temp/ipykernel_29848/1830752982.py:59: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   training = np.array(training)
# C:\ProgramData\Anaconda3\lib\site-packages\keras\optimizer_v2\gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# Epoch 1/200
# 14/14 [==============================] - 0s 2ms/step - loss: 3.3402 - accuracy: 0.0441
# Epoch 2/200
# 14/14 [==============================] - 0s 2ms/step - loss: 3.1556 - accuracy: 0.0735
# Epoch 3/200
# 14/14 [==============================] - 0s 1ms/step - loss: 3.0368 - accuracy: 0.1176
# Epoch 4/200
# 14/14 [==============================] - 0s 2ms/step - loss: 2.9586 - accuracy: 0.2941
# Epoch 5/200
# 14/14 [==============================] - 0s 2ms/step - loss: 2.8275 - accuracy: 0.3088
# Epoch 6/200
# 14/14 [==============================] - 0s 2ms/step - loss: 2.7103 - accuracy: 0.3529
# Epoch 7/200
# 14/14 [==============================] - 0s 2ms/step - loss: 2.6099 - accuracy: 0.3235
# Epoch 8/200
# 14/14 [==============================] - 0s 2ms/step - loss: 2.2929 - accuracy: 0.4559
# Epoch 9/200
# 14/14 [==============================] - 0s 2ms/step - loss: 2.1446 - accuracy: 0.5294
# Epoch 10/200
# 14/14 [==============================] - 0s 1ms/step - loss: 2.0780 - accuracy: 0.5441
# Epoch 11/200
# 14/14 [==============================] - 0s 2ms/step - loss: 1.7259 - accuracy: 0.6029
# Epoch 12/200
# 14/14 [==============================] - 0s 1ms/step - loss: 1.6995 - accuracy: 0.5147
# Epoch 13/200
# 14/14 [==============================] - 0s 1ms/step - loss: 1.6471 - accuracy: 0.4706
# Epoch 14/200
# 14/14 [==============================] - 0s 2ms/step - loss: 1.2527 - accuracy: 0.6176
# Epoch 15/200
# 14/14 [==============================] - 0s 1ms/step - loss: 1.2786 - accuracy: 0.6618
# Epoch 16/200
# 14/14 [==============================] - 0s 1ms/step - loss: 1.2873 - accuracy: 0.6765
# Epoch 17/200
# 14/14 [==============================] - 0s 2ms/step - loss: 1.2279 - accuracy: 0.5735
# Epoch 18/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.8436 - accuracy: 0.7647
# Epoch 19/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.9762 - accuracy: 0.7794
# Epoch 20/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.6974 - accuracy: 0.8529
# Epoch 21/200
# 14/14 [==============================] - 0s 1ms/step - loss: 1.0198 - accuracy: 0.7206
# Epoch 22/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.6064 - accuracy: 0.8824
# Epoch 23/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.8405 - accuracy: 0.7353
# Epoch 24/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.6853 - accuracy: 0.8235
# Epoch 25/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.6706 - accuracy: 0.7941
# Epoch 26/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.4235 - accuracy: 0.8824
# Epoch 27/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.5849 - accuracy: 0.8235
# Epoch 28/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.5862 - accuracy: 0.8382
# Epoch 29/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.4503 - accuracy: 0.8824
# Epoch 30/200
# 14/14 [==============================] - 0s 988us/step - loss: 0.4959 - accuracy: 0.8529
# Epoch 31/200
# 14/14 [==============================] - 0s 935us/step - loss: 0.7282 - accuracy: 0.8235
# Epoch 32/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.3732 - accuracy: 0.9412
# Epoch 33/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.4022 - accuracy: 0.8676
# Epoch 34/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.4316 - accuracy: 0.8824
# Epoch 35/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.4571 - accuracy: 0.8824
# Epoch 36/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.5894 - accuracy: 0.7353
# Epoch 37/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.4785 - accuracy: 0.8676
# Epoch 38/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.2443 - accuracy: 0.9265
# Epoch 39/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.4368 - accuracy: 0.8824
# Epoch 40/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.2483 - accuracy: 0.9265
# Epoch 41/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.2508 - accuracy: 0.9559
# Epoch 42/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.3321 - accuracy: 0.8676
# Epoch 43/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.2522 - accuracy: 0.9265
# Epoch 44/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.2936 - accuracy: 0.8971
# Epoch 45/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.2734 - accuracy: 0.9559
# Epoch 46/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.2005 - accuracy: 0.9559
# Epoch 47/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.3223 - accuracy: 0.9265
# Epoch 48/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.3584 - accuracy: 0.9118
# Epoch 49/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.2439 - accuracy: 0.9559
# Epoch 50/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.3501 - accuracy: 0.8971
# Epoch 51/200
# 14/14 [==============================] - 0s 970us/step - loss: 0.3931 - accuracy: 0.8971
# Epoch 52/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.1898 - accuracy: 0.9706
# Epoch 53/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.3036 - accuracy: 0.9265
# Epoch 54/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.2600 - accuracy: 0.9412
# Epoch 55/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.3958 - accuracy: 0.9412
# Epoch 56/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.3695 - accuracy: 0.8676
# Epoch 57/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.1183 - accuracy: 0.9853
# Epoch 58/200
# 14/14 [==============================] - 0s 997us/step - loss: 0.1681 - accuracy: 0.9706
# Epoch 59/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.4172 - accuracy: 0.8971
# Epoch 60/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.2304 - accuracy: 0.9265
# Epoch 61/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2525 - accuracy: 0.9265
# Epoch 62/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.2702 - accuracy: 0.9412
# Epoch 63/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1609 - accuracy: 0.9559
# Epoch 64/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.1758 - accuracy: 0.9706
# Epoch 65/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.1628 - accuracy: 0.9559
# Epoch 66/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1970 - accuracy: 0.9412
# Epoch 67/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.3352 - accuracy: 0.9265
# Epoch 68/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.2422 - accuracy: 0.9412
# Epoch 69/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1975 - accuracy: 0.9265
# Epoch 70/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1946 - accuracy: 0.9412
# Epoch 71/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1189 - accuracy: 0.9706
# Epoch 72/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1788 - accuracy: 0.9412
# Epoch 73/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.2480 - accuracy: 0.9118
# Epoch 74/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1420 - accuracy: 0.9559
# Epoch 75/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0782 - accuracy: 1.0000
# Epoch 76/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1220 - accuracy: 0.9706
# Epoch 77/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1506 - accuracy: 0.9706
# Epoch 78/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.2704 - accuracy: 0.9412
# Epoch 79/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0940 - accuracy: 1.0000
# Epoch 80/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.1858 - accuracy: 0.9559
# Epoch 81/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.1099 - accuracy: 0.9706
# Epoch 82/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.1062 - accuracy: 0.9706
# Epoch 83/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.1296 - accuracy: 0.9853
# Epoch 84/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.1364 - accuracy: 0.9706
# Epoch 85/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.1165 - accuracy: 0.9853
# Epoch 86/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.1585 - accuracy: 0.9559
# Epoch 87/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.1019 - accuracy: 0.9706
# Epoch 88/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.1746 - accuracy: 0.9412
# Epoch 89/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.1171 - accuracy: 0.9706
# Epoch 90/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.1042 - accuracy: 0.9706
# Epoch 91/200
# 14/14 [==============================] - 0s 998us/step - loss: 0.2381 - accuracy: 0.9265
# Epoch 92/200
# 14/14 [==============================] - 0s 925us/step - loss: 0.0915 - accuracy: 0.9706
# Epoch 93/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.1884 - accuracy: 0.9412
# Epoch 94/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.1038 - accuracy: 0.9706
# Epoch 95/200
# 14/14 [==============================] - 0s 998us/step - loss: 0.0624 - accuracy: 0.9706
# Epoch 96/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.1931 - accuracy: 0.9706
# Epoch 97/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.1026 - accuracy: 0.9706
# Epoch 98/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.1083 - accuracy: 0.9853
# Epoch 99/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.1366 - accuracy: 0.9559
# Epoch 100/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0884 - accuracy: 0.9853
# Epoch 101/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.1335 - accuracy: 0.9853
# Epoch 102/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.1177 - accuracy: 0.9559
# Epoch 103/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1370 - accuracy: 0.9412
# Epoch 104/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.1549 - accuracy: 0.9706
# Epoch 105/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.1752 - accuracy: 0.9706
# Epoch 106/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1209 - accuracy: 0.9559
# Epoch 107/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0747 - accuracy: 0.9853
# Epoch 108/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0786 - accuracy: 0.9706
# Epoch 109/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.1079 - accuracy: 0.9559
# Epoch 110/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0718 - accuracy: 0.9706
# Epoch 111/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0982 - accuracy: 0.9706
# Epoch 112/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0663 - accuracy: 0.9853
# Epoch 113/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.1157 - accuracy: 0.9706
# Epoch 114/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.1548 - accuracy: 0.9559
# Epoch 115/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0626 - accuracy: 0.9853
# Epoch 116/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.1256 - accuracy: 0.9559
# Epoch 117/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0796 - accuracy: 0.9853
# Epoch 118/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.1193 - accuracy: 0.9706
# Epoch 119/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.1375 - accuracy: 0.9265
# Epoch 120/200
# 14/14 [==============================] - 0s 991us/step - loss: 0.1424 - accuracy: 0.9559
# Epoch 121/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0624 - accuracy: 0.9853
# Epoch 122/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0518 - accuracy: 1.0000
# Epoch 123/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0775 - accuracy: 0.9853
# Epoch 124/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.2187 - accuracy: 0.9265
# Epoch 125/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.1000 - accuracy: 0.9706
# Epoch 126/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0591 - accuracy: 0.9853
# Epoch 127/200
# 14/14 [==============================] - 0s 998us/step - loss: 0.1284 - accuracy: 0.9853
# Epoch 128/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.1132 - accuracy: 0.9706
# Epoch 129/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0357 - accuracy: 1.0000
# Epoch 130/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0666 - accuracy: 0.9853
# Epoch 131/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1183 - accuracy: 0.9559
# Epoch 132/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0832 - accuracy: 0.9706
# Epoch 133/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.1220 - accuracy: 0.9706
# Epoch 134/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1172 - accuracy: 0.9706
# Epoch 135/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0680 - accuracy: 1.0000
# Epoch 136/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.1910 - accuracy: 0.9412
# Epoch 137/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0549 - accuracy: 0.9853
# Epoch 138/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0588 - accuracy: 0.9706
# Epoch 139/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0723 - accuracy: 0.9706
# Epoch 140/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1145 - accuracy: 0.9706
# Epoch 141/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0791 - accuracy: 0.9853
# Epoch 142/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0696 - accuracy: 0.9853
# Epoch 143/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.1172 - accuracy: 0.9706
# Epoch 144/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0553 - accuracy: 0.9853
# Epoch 145/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0543 - accuracy: 1.0000
# Epoch 146/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0329 - accuracy: 0.9853
# Epoch 147/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0798 - accuracy: 0.9853
# Epoch 148/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.1750 - accuracy: 0.9706
# Epoch 149/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0770 - accuracy: 0.9706
# Epoch 150/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0891 - accuracy: 0.9706
# Epoch 151/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.2005 - accuracy: 0.9412
# Epoch 152/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0779 - accuracy: 0.9706
# Epoch 153/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0925 - accuracy: 0.9853
# Epoch 154/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.1541 - accuracy: 0.9412
# Epoch 155/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0895 - accuracy: 0.9706
# Epoch 156/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0877 - accuracy: 0.9853
# Epoch 157/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0782 - accuracy: 0.9853
# Epoch 158/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0472 - accuracy: 1.0000
# Epoch 159/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0457 - accuracy: 0.9853
# Epoch 160/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0395 - accuracy: 0.9706
# Epoch 161/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0537 - accuracy: 1.0000
# Epoch 162/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0800 - accuracy: 0.9853
# Epoch 163/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.1141 - accuracy: 0.9706
# Epoch 164/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0719 - accuracy: 0.9706
# Epoch 165/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0887 - accuracy: 0.9559
# Epoch 166/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.1112 - accuracy: 0.9706
# Epoch 167/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0281 - accuracy: 1.0000
# Epoch 168/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0674 - accuracy: 0.9706
# Epoch 169/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0401 - accuracy: 0.9853
# Epoch 170/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.2001 - accuracy: 0.9559
# Epoch 171/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0365 - accuracy: 1.0000
# Epoch 172/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0644 - accuracy: 0.9853
# Epoch 173/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0661 - accuracy: 0.9853
# Epoch 174/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1251 - accuracy: 0.9559
# Epoch 175/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0215 - accuracy: 1.0000
# Epoch 176/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0539 - accuracy: 0.9853
# Epoch 177/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0449 - accuracy: 0.9853
# Epoch 178/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.1056 - accuracy: 0.9706
# Epoch 179/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0670 - accuracy: 0.9853
# Epoch 180/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1300 - accuracy: 0.9412
# Epoch 181/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0268 - accuracy: 1.0000
# Epoch 182/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0237 - accuracy: 1.0000
# Epoch 183/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.1323 - accuracy: 0.9265
# Epoch 184/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0796 - accuracy: 0.9706
# Epoch 185/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.1192 - accuracy: 0.9412
# Epoch 186/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0144 - accuracy: 1.0000
# Epoch 187/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0384 - accuracy: 1.0000
# Epoch 188/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0364 - accuracy: 1.0000
# Epoch 189/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0672 - accuracy: 0.9706
# Epoch 190/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.1133 - accuracy: 0.9559
# Epoch 191/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0973 - accuracy: 0.9853
# Epoch 192/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.1198 - accuracy: 0.9706
# Epoch 193/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.1004 - accuracy: 0.9853
# Epoch 194/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0533 - accuracy: 0.9853
# Epoch 195/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0531 - accuracy: 0.9853
# Epoch 196/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0706 - accuracy: 0.9706
# Epoch 197/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0912 - accuracy: 0.9853
# Epoch 198/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.1667 - accuracy: 0.9412
# Epoch 199/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0549 - accuracy: 0.9706
# Epoch 200/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0669 - accuracy: 0.9706
# model created

# %%
# pip install tensorflow==2.8.0
# pip install Keras

# %%
import os
import random
import json
from keras.models import load_model
import numpy as np
import pickle
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# %%
pwd

# %%
nltk.download('omw-1.4')
model = load_model(os.path.join( 'chatbot_model.h5'))
intents = json.loads(
    open(os.path.join( 'intents.json')).read())
# intents = json.loads(open(os.path.join( 'intents.json')).read().decode("utf-8-sig"))
words = pickle.load(
    open(os.path.join(  'words.pkl'), 'rb'))
classes = pickle.load(
    open(os.path.join(  'classes.pkl'), 'rb'))

print('words', words)
print('classes', classes)


def clean_up_sentence(sentence):
    # tokenize the pattern - splitting words into array
    sentence_words = nltk.word_tokenize(sentence)
    # stemming every word - reducing to base form
    sentence_words = [lemmatizer.lemmatize(
        word.lower()) for word in sentence_words]
    return sentence_words


# return bag of words array: 0 or 1 for words that exist in sentence
def bag_of_words(sentence, words, show_details=True):
    # tokenizing patterns
    sentence_words = clean_up_sentence(sentence)
    # bag of words - vocabulary matrix
    bag = [0]*len(words)
    for s in sentence_words:
        for i, word in enumerate(words):
            if word == s:
                # assign 1 if current word is in the vocabulary position
                bag[i] = 1
                #if show_details:
                    #print("found in bag: %s" % word)
    #print("np.array(bag)", np.array(bag))
    return(np.array(bag))


def predict_class(sentence):
    # filter below  threshold predictions
    p = bag_of_words(sentence, words, show_details=True)
    flag = False
    return_list = []
    for x in p:
        if x == 1:
            flag = True
    if (flag == True):
        res = model.predict(np.array([p]))[0]
        ERROR_THRESHOLD = 0.25
        results = [[i, r] for i, r in enumerate(res) if r > ERROR_THRESHOLD]
        # sorting strength probability
        results.sort(key=lambda x: x[1], reverse=True)

        #print("result", results)
        for r in results:
            return_list.append(
                {"intent": classes[r[0]], "probability": str(r[1])})
    else:
        return_list.append({"intent": "noanswer", "probability": str(1)})

    return return_list


def getResponse(ints, intents_json):
    tag = ints[0]['intent']
    list_of_intents = intents_json['intents']
    for i in list_of_intents:
        if(i['tag'] == tag):
            result = random.choice(i['responses'])
            break
    return result


def chatbot_response(msg):
    ints = predict_class(msg)
    #print('ints', ints)
    res = getResponse(ints, intents)
    #print('res', res)
    return res
# Out:
# words ["'", "'booster", "'s", "'three", '(', ')', '19', 'a', 'about', 'after', 'alot', 'am', 'an', 'and', 'antibiotic', 'any', 'anyone', 'appointment', 'are', 'awesome', 'between', 'book', 'booster', 'bubye', 'by', 'bye', 'can', 'card', 'catch', 'cause', 'chatting', 'clinic', 'coronavirus', 'covid', 'covid-19', 'cure', 'cya', 'difference', 'different', 'disease', 'do', 'doe', 'dose', 'drug', 'effect', 'effected', 'effective', 'even', 'everyone', 'flu', 'follow', 'for', 'from', 'get', 'goodbye', 'have', 'having', 'health', 'hello', 'helpful', 'helping', 'hey', 'heylo', 'hi', 'hola', 'how', 'i', 'if', 'in', 'incubation', 'infection', 'influenza', 'is', 'last', 'later', 'likely', 'long', 'major', 'me', 'measure', 'medicine', 'much', 'myself', 'next', 'nice', 'not', 'of', 'ontario', 'or', 'para', 'period', 'positive', 'prevent', 'preventing', 'primary', 'protect', 'protection', 'public', 'red', 'required', 'see', 'series', 'should', 'side', 'so', 'spread', 'still', 'surface', 'symptom', 'test', 'thank', 'thanks', 'that', 'the', 'therapy', 'there', 'third', 'till', 'time', 'to', 'touching', 'transpo', 'transportation', 'treating', 'treatment', 'vaccination', 'vaccine', 'want', 'we', 'what', 'white', 'why', 'worry', 'would', 'you']
# classes ['Are antibiotics effective in preventing or treating the COVID-19', 'Are there any medicines or therapies that can prevent or cure COVID-19', 'COVID-19 vaccine cause a COVID-19 infection', 'COVID-19 vaccine different from the influenza (flu) vaccine', 'How does COVID 19 spread?', 'How likely am I to catch COVID-19?', 'How long can you test positive', 'Is there a vaccine, drug or treatment for COVID-19', 'Should I worry about COVID-19', 'Transportation to COVID-19 vaccination clinics', 'What are the symptoms of COVID 19?', 'What can I do to protect myself and prevent the spread of disease?', 'What is COVID-19?', 'What is a coronavirus?', 'Why would I want to get the COVID-19 vaccine', 'appointment if I do not have an Ontario health card', "difference between a 'three dose primary series' and a 'booster dose'?", 'get virus by touching surfaces', 'goodbye', 'greeting', 'incubation period', 'prevent COVID-19', 'thanks', 'third (booster) dose of the COVID-19 vaccine', 'vaccine side effects last']
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\shefi\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
# test chatbot 
from termcolor import colored
print ("CHAT START (BLANK AND ENTER TO STOP)")
try:
    while (1):
        x=input(colored("YOU:",'red'))
        if (x.strip()==""):
            break
        print ( colored("CHATBOT:",'blue'), colored(chatbot_response(x),'green'))
except:
    print("ERROR")

print("CHAT END")
# Out:
# CHAT START (BLANK AND ENTER TO STOP)
# YOU:what are the symptoms of coronavirus
# CHATBOT: The most common symptoms of COVID-19 are fever, tiredness, and dry cough. Some patients may have aches and pains, nasal congestion, runny nose, sore throat or diarrhea. These symptoms are usually mild and begin gradually. Some people become infected but dont develop any symptoms and don't feel unwell. Most people (about 80%) recover from the disease without needing special treatment. Around 1 out of every 6 people who gets COVID-19 becomes seriously ill and develops difficulty breathing. Older people, and those with underlying medical problems like high blood pressure, heart problems or diabetes, are more likely to develop serious illness. People with fever, cough and difficulty breathing should seek medical attention.
